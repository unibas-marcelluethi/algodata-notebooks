# %% [markdown]
# # Test notebook

# %% [markdown]
# The purpose of this notebook is to illustrate how binder works.

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
t = np.linspace(0, 100, 1000)
ft = np.sin(t)

# %%
fig, ax = plt.subplots()
ax.plot(t, ft)
